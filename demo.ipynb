# %% [markdown]
# Create widget to display image

# %%
import ipywidgets
from IPython.display import display

image_w = ipywidgets.Image(format='jpeg')

display(image_w)
# Out:
# Image(value=b'', format='jpeg')

# %% [markdown]
# Initialize the PoseEstimation module

# %%
from scripts.pose_estimation import PoseEstimation

pose_estimation = PoseEstimation(image_w)

# %% [markdown]
# Run estimation on camera frame

# %%
pose_estimation.capture()
# Out:
# nose at 122, 71
# left_eye at 140, 51
# right_eye at 112, 57
# left_ear at 167, 89
# left_shoulder at 199, 176
# right_shoulder at 73, 186
# neck at 134, 181
# processed image
# {'nose': [122, 71], 'left_eye': [140, 51], 'right_eye': [112, 57], 'left_ear': [167, 89], 'left_shoulder': [199, 176], 'right_shoulder': [73, 186], 'neck': [134, 181]}

# %% [markdown]
# Run pose estimation on camera stream

# %%
pose_estimation.start_stream()
# Out:
# ft_ear at 152, 18
# left_shoulder at 195, 134
# right_shoulder at 67, 143
# neck at 131, 141
# processed image
# {'nose': [108, 2], 'left_ear': [152, 18], 'left_shoulder': [195, 134], 'right_shoulder': [67, 143], 'neck': [131, 141]}
# nose at 108, 2
# left_ear at 152, 15
# left_shoulder at 197, 134
# right_shoulder at 66, 146
# neck at 130, 142
# processed image
# {'nose': [108, 2], 'left_ear': [152, 15], 'left_shoulder': [197, 134], 'right_shoulder': [66, 146], 'neck': [130, 142]}
# nose at 108, 2
# left_ear at 152, 17
# left_shoulder at 197, 133
# right_shoulder at 66, 143
# neck at 131, 141
# processed image
# {'nose': [108, 2], 'left_ear': [152, 17], 'left_shoulder': [197, 133], 'right_shoulder': [66, 143], 'neck': [131, 141]}
# nose at 109, 2
# left_ear at 153, 19
# left_shoulder at 197, 135
# right_shoulder at 66, 146
# neck at 131, 142
# processed image
# {'nose': [109, 2], 'left_ear': [153, 19], 'left_shoulder': [197, 135], 'right_shoulder': [66, 146], 'neck': [131, 142]}
# nose at 111, 2
# left_ear at 154, 20
# left_shoulder at 198, 135
# right_shoulder at 67, 146
# neck at 133, 142
# processed image
# {'nose': [111, 2], 'left_ear': [154, 20], 'left_shoulder': [198, 135], 'right_shoulder': [67, 146], 'neck': [133, 142]}
# nose at 111, 2
# left_ear at 154, 19
# left_shoulder at 199, 137
# right_shoulder at 66, 147
# neck at 133, 143
# processed image
# {'nose': [111, 2], 'left_ear': [154, 19], 'left_shoulder': [199, 137], 'right_shoulder': [66, 147], 'neck': [133, 143]}
# nose at 110, 2
# left_ear at 153, 18
# left_shoulder at 198, 136
# right_shoulder at 65, 146
# neck at 131, 143
# processed image
# {'nose': [110, 2], 'left_ear': [153, 18], 'left_shoulder': [198, 136], 'right_shoulder': [65, 146], 'neck': [131, 143]}
# nose at 110, 2
# left_ear at 153, 17
# left_shoulder at 197, 135
# right_shoulder at 66, 143
# neck at 131, 141
# processed image
# {'nose': [110, 2], 'left_ear': [153, 17], 'left_shoulder': [197, 135], 'right_shoulder': [66, 143], 'neck': [131, 141]}
# nose at 107, 19
# left_eye at 122, 2
# right_eye at 97, 3
# left_ear at 151, 30
# left_shoulder at 195, 155
# right_shoulder at 63, 164
# neck at 129, 162
# processed image
# {'nose': [107, 19], 'left_eye': [122, 2], 'right_eye': [97, 3], 'left_ear': [151, 30], 'left_shoulder': [195, 155], 'right_shoulder': [63, 164], 'neck': [129, 162]}
# nose at 109, 73
# left_eye at 124, 51
# right_eye at 99, 60
# left_ear at 151, 83
# processed image
# {'nose': [109, 73], 'left_eye': [124, 51], 'right_eye': [99, 60], 'left_ear': [151, 83]}
# nose at 109, 116
# left_eye at 124, 95
# right_eye at 99, 105
# left_ear at 153, 129
# processed image
# {'nose': [109, 116], 'left_eye': [124, 95], 'right_eye': [99, 105], 'left_ear': [153, 129]}
# nose at 114, 127
# left_eye at 130, 105
# right_eye at 104, 114
# left_ear at 159, 139
# processed image
# {'nose': [114, 127], 'left_eye': [130, 105], 'right_eye': [104, 114], 'left_ear': [159, 139]}
# nose at 113, 91
# left_eye at 129, 69
# right_eye at 102, 79
# left_ear at 157, 101
# processed image
# {'nose': [113, 91], 'left_eye': [129, 69], 'right_eye': [102, 79], 'left_ear': [157, 101]}
# nose at 120, 91
# left_eye at 136, 69
# right_eye at 108, 78
# left_ear at 163, 102
# processed image
# {'nose': [120, 91], 'left_eye': [136, 69], 'right_eye': [108, 78], 'left_ear': [163, 102]}
# nose at 129, 81
# left_eye at 144, 58
# right_eye at 118, 68
# left_ear at 172, 87
# right_ear at 110, 92
# right_shoulder at 87, 222
# neck at 151, 222
# processed image
# {'nose': [129, 81], 'left_eye': [144, 58], 'right_eye': [118, 68], 'left_ear': [172, 87], 'right_ear': [110, 92], 'right_shoulder': [87, 222], 'neck': [151, 222]}
# nose at 131, 75
# left_eye at 146, 52
# right_eye at 119, 61
# left_ear at 173, 83
# right_ear at 110, 88
# left_shoulder at 219, 206
# right_shoulder at 86, 220
# neck at 153, 219
# processed image
# {'nose': [131, 75], 'left_eye': [146, 52], 'right_eye': [119, 61], 'left_ear': [173, 83], 'right_ear': [110, 88], 'left_shoulder': [219, 206], 'right_shoulder': [86, 220], 'neck': [153, 219]}
# nose at 127, 50
# left_eye at 143, 26
# right_eye at 116, 35
# left_ear at 170, 57
# right_shoulder at 83, 194
# neck at 149, 194
# processed image
# {'nose': [127, 50], 'left_eye': [143, 26], 'right_eye': [116, 35], 'left_ear': [170, 57], 'right_shoulder': [83, 194], 'neck': [149, 194]}
# nose at 128, 32
# left_eye at 144, 14
# right_eye at 117, 22
# left_ear at 171, 43
# left_shoulder at 209, 163
# right_shoulder at 84, 174
# neck at 146, 170
# processed image
# {'nose': [128, 32], 'left_eye': [144, 14], 'right_eye': [117, 22], 'left_ear': [171, 43], 'left_shoulder': [209, 163], 'right_shoulder': [84, 174], 'neck': [146, 170]}
# nose at 127, 28
# left_eye at 143, 4
# right_eye at 116, 14
# left_ear at 171, 38
# left_shoulder at 214, 163
# right_shoulder at 82, 170
# neck at 147, 169
# processed image
# {'nose': [127, 28], 'left_eye': [143, 4], 'right_eye': [116, 14], 'left_ear': [171, 38], 'left_shoulder': [214, 163], 'right_shoulder': [82, 170], 'neck': [147, 169]}
# nose at 128, 23
# left_eye at 144, 2
# right_eye at 117, 9
# left_ear at 171, 33
# left_shoulder at 213, 166
# right_shoulder at 77, 166
# neck at 145, 167
# processed image
# {'nose': [128, 23], 'left_eye': [144, 2], 'right_eye': [117, 9], 'left_ear': [171, 33], 'left_shoulder': [213, 166], 'right_shoulder': [77, 166], 'neck': [145, 167]}
# nose at 127, 10
# left_ear at 170, 23
# left_shoulder at 213, 158
# right_shoulder at 75, 150
# neck at 142, 155
# processed image
# {'nose': [127, 10], 'left_ear': [170, 23], 'left_shoulder': [213, 158], 'right_shoulder': [75, 150], 'neck': [142, 155]}
# nose at 128, 3
# left_ear at 169, 23
# left_shoulder at 209, 147
# right_shoulder at 75, 142
# neck at 143, 146
# processed image
# {'nose': [128, 3], 'left_ear': [169, 23], 'left_shoulder': [209, 147], 'right_shoulder': [75, 142], 'neck': [143, 146]}
# nose at 124, 18
# left_eye at 142, 2
# right_eye at 114, 2
# left_ear at 169, 23
# left_shoulder at 207, 166
# right_shoulder at 70, 159
# neck at 136, 164
# processed image
# {'nose': [124, 18], 'left_eye': [142, 2], 'right_eye': [114, 2], 'left_ear': [169, 23], 'left_shoulder': [207, 166], 'right_shoulder': [70, 159], 'neck': [136, 164]}
# nose at 121, 61
# left_eye at 138, 41
# right_eye at 110, 44
# left_ear at 164, 75
# left_shoulder at 204, 205
# right_shoulder at 70, 198
# neck at 131, 204
# processed image
# {'nose': [121, 61], 'left_eye': [138, 41], 'right_eye': [110, 44], 'left_ear': [164, 75], 'left_shoulder': [204, 205], 'right_shoulder': [70, 198], 'neck': [131, 204]}
# nose at 124, 61
# left_eye at 141, 42
# right_eye at 113, 46
# left_ear at 166, 78
# left_shoulder at 206, 206
# right_shoulder at 71, 199
# neck at 134, 207
# processed image
# {'nose': [124, 61], 'left_eye': [141, 42], 'right_eye': [113, 46], 'left_ear': [166, 78], 'left_shoulder': [206, 206], 'right_shoulder': [71, 199], 'neck': [134, 207]}
# nose at 121, 74
# left_eye at 139, 54
# right_eye at 112, 58
# left_ear at 165, 90
# left_shoulder at 203, 219
# right_shoulder at 70, 212
# neck at 134, 219
# processed image
# {'nose': [121, 74], 'left_eye': [139, 54], 'right_eye': [112, 58], 'left_ear': [165, 90], 'left_shoulder': [203, 219], 'right_shoulder': [70, 212], 'neck': [134, 219]}
# nose at 122, 83
# left_eye at 139, 64
# right_eye at 113, 67
# left_ear at 165, 99
# right_shoulder at 72, 222
# neck at 137, 222
# processed image
# {'nose': [122, 83], 'left_eye': [139, 64], 'right_eye': [113, 67], 'left_ear': [165, 99], 'right_shoulder': [72, 222], 'neck': [137, 222]}
# nose at 128, 101
# left_eye at 144, 80
# right_eye at 117, 86
# left_ear at 170, 115
# processed image
# {'nose': [128, 101], 'left_eye': [144, 80], 'right_eye': [117, 86], 'left_ear': [170, 115]}
# nose at 130, 97
# left_eye at 147, 76
# right_eye at 119, 82
# left_ear at 173, 112
# processed image
# {'nose': [130, 97], 'left_eye': [147, 76], 'right_eye': [119, 82], 'left_ear': [173, 112]}
# nose at 130, 89
# left_eye at 147, 70
# right_eye at 120, 76
# left_ear at 174, 106
# right_shoulder at 80, 222
# processed image
# {'nose': [130, 89], 'left_eye': [147, 70], 'right_eye': [120, 76], 'left_ear': [174, 106], 'right_shoulder': [80, 222]}
# nose at 132, 80
# left_eye at 149, 59
# right_eye at 122, 65
# left_ear at 177, 91
# right_shoulder at 82, 220
# neck at 147, 222
# processed image
# {'nose': [132, 80], 'left_eye': [149, 59], 'right_eye': [122, 65], 'left_ear': [177, 91], 'right_shoulder': [82, 220], 'neck': [147, 222]}
# nose at 134, 57
# left_eye at 151, 41
# right_eye at 124, 45
# left_ear at 179, 70
# left_shoulder at 215, 198
# right_shoulder at 88, 197
# neck at 151, 201
# processed image
# {'nose': [134, 57], 'left_eye': [151, 41], 'right_eye': [124, 45], 'left_ear': [179, 70], 'left_shoulder': [215, 198], 'right_shoulder': [88, 197], 'neck': [151, 201]}
# nose at 135, 43
# left_eye at 151, 25
# right_eye at 123, 30
# left_ear at 178, 59
# right_ear at 114, 58
# left_shoulder at 222, 186
# right_shoulder at 86, 186
# neck at 153, 187
# processed image
# {'nose': [135, 43], 'left_eye': [151, 25], 'right_eye': [123, 30], 'left_ear': [178, 59], 'right_ear': [114, 58], 'left_shoulder': [222, 186], 'right_shoulder': [86, 186], 'neck': [153, 187]}
# nose at 132, 25
# left_eye at 148, 2
# right_eye at 121, 11
# left_ear at 175, 35
# right_ear at 111, 34
# left_shoulder at 211, 159
# right_shoulder at 85, 167
# neck at 150, 166
# processed image
# {'nose': [132, 25], 'left_eye': [148, 2], 'right_eye': [121, 11], 'left_ear': [175, 35], 'right_ear': [111, 34], 'left_shoulder': [211, 159], 'right_shoulder': [85, 167], 'neck': [150, 166]}
# nose at 131, 4
# left_ear at 174, 19
# left_shoulder at 214, 139
# right_shoulder at 86, 151
# neck at 150, 146
# processed image
# {'nose': [131, 4], 'left_ear': [174, 19], 'left_shoulder': [214, 139], 'right_shoulder': [86, 151], 'neck': [150, 146]}
# nose at 130, 2
# left_ear at 172, 17
# left_shoulder at 214, 133
# right_shoulder at 86, 146
# neck at 149, 141
# processed image
# {'nose': [130, 2], 'left_ear': [172, 17], 'left_shoulder': [214, 133], 'right_shoulder': [86, 146], 'neck': [149, 141]}
# nose at 128, 2
# left_ear at 170, 18
# left_shoulder at 213, 133
# right_shoulder at 85, 146
# neck at 150, 139
# processed image
# {'nose': [128, 2], 'left_ear': [170, 18], 'left_shoulder': [213, 133], 'right_shoulder': [85, 146], 'neck': [150, 139]}
# nose at 128, 2
# left_ear at 170, 17
# left_shoulder at 213, 136
# right_shoulder at 85, 146
# neck at 147, 143
# processed image
# {'nose': [128, 2], 'left_ear': [170, 17], 'left_shoulder': [213, 136], 'right_shoulder': [85, 146], 'neck': [147, 143]}
# nose at 128, 2
# left_ear at 170, 17
# left_shoulder at 213, 131
# right_shoulder at 85, 142
# neck at 149, 138
# processed image
# {'nose': [128, 2], 'left_ear': [170, 17], 'left_shoulder': [213, 131], 'right_shoulder': [85, 142], 'neck': [149, 138]}
# nose at 127, 2
# left_ear at 169, 15
# left_shoulder at 210, 131
# right_shoulder at 83, 139
# neck at 146, 137
# processed image
# {'nose': [127, 2], 'left_ear': [169, 15], 'left_shoulder': [210, 131], 'right_shoulder': [83, 139], 'neck': [146, 137]}
# nose at 126, 2
# left_ear at 169, 15
# left_shoulder at 213, 131
# right_shoulder at 82, 139
# neck at 146, 137
# processed image
# {'nose': [126, 2], 'left_ear': [169, 15], 'left_shoulder': [213, 131], 'right_shoulder': [82, 139], 'neck': [146, 137]}
# nose at 127, 2
# left_ear at 169, 15
# left_shoulder at 211, 130
# right_shoulder at 82, 139
# neck at 146, 135
# processed image
# {'nose': [127, 2], 'left_ear': [169, 15], 'left_shoulder': [211, 130], 'right_shoulder': [82, 139], 'neck': [146, 135]}
# nose at 126, 2
# left_ear at 169, 14
# left_shoulder at 209, 130
# right_shoulder at 81, 139
# neck at 145, 135
# processed image
# {'nose': [126, 2], 'left_ear': [169, 14], 'left_shoulder': [209, 130], 'right_shoulder': [81, 139], 'neck': [145, 135]}
# nose at 125, 2
# left_ear at 169, 15
# left_shoulder at 210, 131
# right_shoulder at 82, 137
# neck at 145, 135
# processed image
# {'nose': [125, 2], 'left_ear': [169, 15], 'left_shoulder': [210, 131], 'right_shoulder': [82, 137], 'neck': [145, 135]}
# nose at 125, 2
# left_ear at 169, 13
# left_shoulder at 209, 130
# right_shoulder at 81, 136
# neck at 144, 134
# processed image
# {'nose': [125, 2], 'left_ear': [169, 13], 'left_shoulder': [209, 130], 'right_shoulder': [81, 136], 'neck': [144, 134]}
# nose at 124, 2
# left_ear at 169, 12
# left_shoulder at 209, 129
# right_shoulder at 82, 137
# neck at 145, 134
# processed image
# {'nose': [124, 2], 'left_ear': [169, 12], 'left_shoulder': [209, 129], 'right_shoulder': [82, 137], 'neck': [145, 134]}
# nose at 124, 2
# left_ear at 169, 11
# left_shoulder at 207, 126
# right_shoulder at 81, 134
# neck at 144, 132
# processed image
# {'nose': [124, 2], 'left_ear': [169, 11], 'left_shoulder': [207, 126], 'right_shoulder': [81, 134], 'neck': [144, 132]}
# nose at 122, 2
# left_ear at 169, 11
# left_shoulder at 207, 127
# right_shoulder at 82, 134
# neck at 145, 133
# processed image
# {'nose': [122, 2], 'left_ear': [169, 11], 'left_shoulder': [207, 127], 'right_shoulder': [82, 134], 'neck': [145, 133]}
# nose at 122, 2
# left_ear at 168, 9
# left_shoulder at 209, 129
# right_shoulder at 81, 134
# neck at 145, 133
# processed image
# {'nose': [122, 2], 'left_ear': [168, 9], 'left_shoulder': [209, 129], 'right_shoulder': [81, 134], 'neck': [145, 133]}
# nose at 123, 2
# left_ear at 169, 10
# left_shoulder at 210, 126
# right_shoulder at 82, 132
# neck at 145, 130
# processed image
# {'nose': [123, 2], 'left_ear': [169, 10], 'left_shoulder': [210, 126], 'right_shoulder': [82, 132], 'neck': [145, 130]}
# nose at 123, 2
# left_ear at 168, 11
# left_shoulder at 207, 127
# right_shoulder at 82, 133
# neck at 145, 131
# processed image
# {'nose': [123, 2], 'left_ear': [168, 11], 'left_shoulder': [207, 127], 'right_shoulder': [82, 133], 'neck': [145, 131]}
# nose at 124, 2
# left_ear at 168, 11
# left_shoulder at 210, 127
# right_shoulder at 82, 134
# neck at 145, 132
# processed image
# {'nose': [124, 2], 'left_ear': [168, 11], 'left_shoulder': [210, 127], 'right_shoulder': [82, 134], 'neck': [145, 132]}
# nose at 122, 2
# left_ear at 168, 9
# left_shoulder at 209, 127
# right_shoulder at 82, 133
# neck at 146, 131
# processed image
# {'nose': [122, 2], 'left_ear': [168, 9], 'left_shoulder': [209, 127], 'right_shoulder': [82, 133], 'neck': [146, 131]}
# nose at 122, 2
# left_ear at 168, 8
# left_shoulder at 209, 127
# right_shoulder at 81, 134
# neck at 144, 131
# processed image
# {'nose': [122, 2], 'left_ear': [168, 8], 'left_shoulder': [209, 127], 'right_shoulder': [81, 134], 'neck': [144, 131]}
# nose at 123, 2
# left_ear at 168, 11
# left_shoulder at 209, 126
# right_shoulder at 81, 137
# neck at 146, 133
# processed image
# {'nose': [123, 2], 'left_ear': [168, 11], 'left_shoulder': [209, 126], 'right_shoulder': [81, 137], 'neck': [146, 133]}
# nose at 123, 2
# left_ear at 168, 12
# left_shoulder at 207, 127
# right_shoulder at 82, 137
# neck at 145, 134
# processed image
# {'nose': [123, 2], 'left_ear': [168, 12], 'left_shoulder': [207, 127], 'right_shoulder': [82, 137], 'neck': [145, 134]}
# nose at 123, 2
# left_ear at 168, 12
# left_shoulder at 207, 127
# right_shoulder at 82, 135
# neck at 145, 132
# processed image
# {'nose': [123, 2], 'left_ear': [168, 12], 'left_shoulder': [207, 127], 'right_shoulder': [82, 135], 'neck': [145, 132]}
# nose at 124, 2
# left_ear at 169, 13
# left_shoulder at 210, 127
# right_shoulder at 83, 137
# neck at 145, 133
# processed image
# {'nose': [124, 2], 'left_ear': [169, 13], 'left_shoulder': [210, 127], 'right_shoulder': [83, 137], 'neck': [145, 133]}
# nose at 126, 2
# left_ear at 169, 13
# left_shoulder at 213, 129
# right_shoulder at 82, 137
# neck at 145, 135
# processed image
# {'nose': [126, 2], 'left_ear': [169, 13], 'left_shoulder': [213, 129], 'right_shoulder': [82, 137], 'neck': [145, 135]}
# nose at 125, 2
# left_ear at 169, 13
# left_shoulder at 209, 130
# right_shoulder at 82, 136
# neck at 145, 135
# processed image
# {'nose': [125, 2], 'left_ear': [169, 13], 'left_shoulder': [209, 130], 'right_shoulder': [82, 136], 'neck': [145, 135]}
# nose at 126, 2
# left_ear at 169, 13
# left_shoulder at 210, 131
# right_shoulder at 82, 137
# neck at 145, 135
# processed image
# {'nose': [126, 2], 'left_ear': [169, 13], 'left_shoulder': [210, 131], 'right_shoulder': [82, 137], 'neck': [145, 135]}
# nose at 126, 2
# left_ear at 170, 14
# left_shoulder at 210, 131
# right_shoulder at 82, 139
# neck at 145, 136
# processed image
# {'nose': [126, 2], 'left_ear': [170, 14], 'left_shoulder': [210, 131], 'right_shoulder': [82, 139], 'neck': [145, 136]}
# nose at 127, 9
# right_eye at 114, 2
# left_ear at 170, 26
# left_shoulder at 213, 150
# right_shoulder at 79, 154
# neck at 144, 152
# processed image
# {'nose': [127, 9], 'right_eye': [114, 2], 'left_ear': [170, 26], 'left_shoulder': [213, 150], 'right_shoulder': [79, 154], 'neck': [144, 152]}
# nose at 125, 37
# left_eye at 141, 17
# right_eye at 114, 23
# left_ear at 168, 51
# left_shoulder at 210, 174
# right_shoulder at 79, 179
# neck at 143, 178
# processed image
# {'nose': [125, 37], 'left_eye': [141, 17], 'right_eye': [114, 23], 'left_ear': [168, 51], 'left_shoulder': [210, 174], 'right_shoulder': [79, 179], 'neck': [143, 178]}
# nose at 122, 63
# left_eye at 138, 41
# right_eye at 111, 47
# left_ear at 165, 72
# left_shoulder at 213, 205
# right_shoulder at 75, 207
# neck at 141, 210
# processed image
# {'nose': [122, 63], 'left_eye': [138, 41], 'right_eye': [111, 47], 'left_ear': [165, 72], 'left_shoulder': [213, 205], 'right_shoulder': [75, 207], 'neck': [141, 210]}
# nose at 121, 73
# left_eye at 137, 54
# right_eye at 110, 60
# left_ear at 164, 88
# left_shoulder at 209, 210
# right_shoulder at 74, 216
# neck at 139, 219
# processed image
# {'nose': [121, 73], 'left_eye': [137, 54], 'right_eye': [110, 60], 'left_ear': [164, 88], 'left_shoulder': [209, 210], 'right_shoulder': [74, 216], 'neck': [139, 219]}
# nose at 121, 72
# left_eye at 138, 52
# right_eye at 111, 57
# left_ear at 165, 86
# left_shoulder at 209, 211
# right_shoulder at 77, 215
# neck at 139, 216
# processed image
# {'nose': [121, 72], 'left_eye': [138, 52], 'right_eye': [111, 57], 'left_ear': [165, 86], 'left_shoulder': [209, 211], 'right_shoulder': [77, 215], 'neck': [139, 216]}
# nose at 121, 75
# left_eye at 137, 54
# right_eye at 110, 60
# left_ear at 164, 87
# left_shoulder at 210, 214
# right_shoulder at 76, 219
# neck at 139, 220
# processed image
# {'nose': [121, 75], 'left_eye': [137, 54], 'right_eye': [110, 60], 'left_ear': [164, 87], 'left_shoulder': [210, 214], 'right_shoulder': [76, 219], 'neck': [139, 220]}
# nose at 120, 79
# left_eye at 136, 60
# right_eye at 110, 66
# left_ear at 163, 95
# left_shoulder at 209, 219
# right_shoulder at 74, 220
# neck at 137, 222
# processed image
# {'nose': [120, 79], 'left_eye': [136, 60], 'right_eye': [110, 66], 'left_ear': [163, 95], 'left_shoulder': [209, 219], 'right_shoulder': [74, 220], 'neck': [137, 222]}
# nose at 121, 79
# left_eye at 138, 60
# right_eye at 111, 65
# left_ear at 164, 94
# left_shoulder at 209, 219
# right_shoulder at 76, 220
# neck at 138, 220
# processed image
# {'nose': [121, 79], 'left_eye': [138, 60], 'right_eye': [111, 65], 'left_ear': [164, 94], 'left_shoulder': [209, 219], 'right_shoulder': [76, 220], 'neck': [138, 220]}
# nose at 122, 78
# left_eye at 139, 59
# right_eye at 112, 64
# left_ear at 165, 94
# left_shoulder at 210, 220
# right_shoulder at 77, 220
# neck at 138, 222
# processed image
# {'nose': [122, 78], 'left_eye': [139, 59], 'right_eye': [112, 64], 'left_ear': [165, 94], 'left_shoulder': [210, 220], 'right_shoulder': [77, 220], 'neck': [138, 222]}
# nose at 123, 78
# left_eye at 140, 58
# right_eye at 113, 64
# left_ear at 166, 94
# left_shoulder at 211, 219
# right_shoulder at 78, 220
# neck at 139, 222
# processed image
# {'nose': [123, 78], 'left_eye': [140, 58], 'right_eye': [113, 64], 'left_ear': [166, 94], 'left_shoulder': [211, 219], 'right_shoulder': [78, 220], 'neck': [139, 222]}
# nose at 123, 82
# left_eye at 140, 63
# right_eye at 113, 69
# left_ear at 167, 96
# left_shoulder at 211, 220
# right_shoulder at 78, 222
# neck at 142, 222
# processed image
# {'nose': [123, 82], 'left_eye': [140, 63], 'right_eye': [113, 69], 'left_ear': [167, 96], 'left_shoulder': [211, 220], 'right_shoulder': [78, 222], 'neck': [142, 222]}
# nose at 127, 90
# left_eye at 143, 71
# right_eye at 116, 77
# left_ear at 169, 107
# processed image
# {'nose': [127, 90], 'left_eye': [143, 71], 'right_eye': [116, 77], 'left_ear': [169, 107]}
# nose at 130, 94
# left_eye at 145, 74
# right_eye at 119, 80
# left_ear at 172, 110
# processed image
# {'nose': [130, 94], 'left_eye': [145, 74], 'right_eye': [119, 80], 'left_ear': [172, 110]}
# nose at 131, 91
# left_eye at 147, 71
# right_eye at 121, 78
# left_ear at 175, 104
# processed image
# {'nose': [131, 91], 'left_eye': [147, 71], 'right_eye': [121, 78], 'left_ear': [175, 104]}

# %% [markdown]
# Stop camera stream

# %%
pose_estimation.stop_stream()
# Out:
# nose at 133, 86
# left_eye at 148, 68
# right_eye at 122, 74
# left_ear at 177, 101
# right_ear at 113, 105
# right_shoulder at 87, 222
# processed image
# {'nose': [133, 86], 'left_eye': [148, 68], 'right_eye': [122, 74], 'left_ear': [177, 101], 'right_ear': [113, 105], 'right_shoulder': [87, 222]}
# nose at 133, 77
# left_eye at 149, 59
# right_eye at 122, 66
# left_ear at 176, 93
# right_ear at 113, 94
# right_shoulder at 85, 220
# neck at 153, 220
# processed image
# {'nose': [133, 77], 'left_eye': [149, 59], 'right_eye': [122, 66], 'left_ear': [176, 93], 'right_ear': [113, 94], 'right_shoulder': [85, 220], 'neck': [153, 220]}
